# %%
# Importing relevant packages to carry out data analysis and create visulisations
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
import numpy as np
from datetime import timedelta

# %%
### General functions ###
genders = ['Men', 'Women']

# Function to export dataframe as a markdown table to copy into HackMD
def export_df_as_markdown(dataframe, name):
    markdown_table = dataframe.to_markdown(index=False)
    with open(f'figures/{name}_markdown_table.txt', 'w', encoding='utf-8') as file:
        file.write(markdown_table)

# %%
# Read the Combined Data CSV file and create a dataframe
try:
    df = pd.read_csv('marathon_combined_data.csv')

# Error handling
except FileNotFoundError:
    print("Error: File not found.")
except Exception as e:
    print(f"An error occurred: {e}")

# Convert 'Year' and 'Position' columns to integer values
df['Year'] = df['Year'].astype(int)
df['Position'] = df['Position'].astype(int)

# Showing the 54 year marathon, creating markdown table of line and 
fifty_four_year_marathon = df[(df['Name'] == 'Shizo Kanakuri') & (df['Year'] == 1912)]
export_df_as_markdown(fifty_four_year_marathon, '54_year_marathon')
display(fifty_four_year_marathon)

# Removing 54 year marathon from dataframe as it is a large anomaly in the data that could skew analysis
df = df.drop(fifty_four_year_marathon.index[0]).reset_index(drop=True)

# Adding OR (Olympic Record) for first Women Marathon finisher
first_women_finisher_index = df[(df['Year'] == 1984) & (df['Gender'] == 'Women') & (df['Position'] == 1)].index[0]
df.loc[first_women_finisher_index, 'Notes'] = 'OR'
display(df.loc[first_women_finisher_index])

# Removing notes other than world record (WR) and olympic record (OR) and replacing with '-'
for row in range(len(df)):
    if df.loc[row, 'Notes'] not in ['WR', 'OR']:
        df.loc[row, 'Notes'] = '-'

# Displaying the dataframe
display(df)
# Out:
#     Year   Location Gender  Position            Name Nationality Continent  \
# 71  1912  Stockholm    Men        36  Shizo Kanakuri       Japan      Asia
#
#              Time_Taken Notes
# 71  54:08:06:05:32:20.3   NaN
# Year                    1984
# Location         Los Angeles
# Gender                 Women
# Position                   1
# Name             Joan Benoit
# Nationality    United States
# Continent      North America
# Time_Taken           2:24:52
# Notes                     OR
# Name: 1633, dtype: object
#       Year Location Gender  Position                 Name      Nationality  \
# 0     1896   Athens    Men         1       Spyridon Louis           Greece
# 1     1896   Athens    Men         2  Charilaos Vasilakos           Greece
# 2     1896   Athens    Men         3        Gyula Kellner          Hungary
# 3     1900    Paris    Men         1        Michel Théato           France
# 4     1900    Paris    Men         2       Émile Champion           France
# ...    ...      ...    ...       ...                  ...              ...
# 2331  2020    Tokyo  Women        69       Juliet Chekwel           Uganda
# 2332  2020    Tokyo  Women        70     Catarina Ribeiro         Portugal
# 2333  2020    Tokyo  Women        71        Jess Piasecki    Great Britain
# 2334  2020    Tokyo  Women        72       Sharon Firisua  Solomon Islands
# 2335  2020    Tokyo  Women        73     Dayna Pidhoresky           Canada
#
#           Continent Time_Taken Notes
# 0            Europe    2:58:50    OR
# 1            Europe    3:06:03     -
# 2            Europe    3:06:35     -
# 3            Europe    2:59:45     -
# 4            Europe    3:04:17     -
# ...             ...        ...   ...
# 2331         Africa    2:53:40     -
# 2332         Europe    2:55:01     -
# 2333         Europe    2:55:39     -
# 2334        Oceania    3:02:10     -
# 2335  North America    3:03:10     -
#
# [2336 rows x 9 columns]

# %%
### Time Delta functions to be used

# Function to convert the time string into a time delta format
def time_str_to_time_delta(time_str):
    # Splitting the string into 3 parts by their separation by a colon
    parts = time_str.split(':')
    # Assigning the first part to the hours
    hours = int(parts[0])
    # Assigning the second part to the minutes
    minutes = int(parts[1])
    # Setting microseconds to zero for if there is no microseconds in the string
    microseconds = 0
    if '.' in parts[2]:
        seconds, tenths = map(int, parts[2].split('.'))
        microseconds = tenths * 100000
    else:
        seconds = int(parts[2])
    return timedelta(hours=hours, minutes=minutes, seconds=seconds, microseconds=microseconds)

df['Time'] = df['Time_Taken'].apply(time_str_to_time_delta)

#### !!!! Might not need instead use diff()!!!!!!
def time_difference(time_1, time_2):
    if time_2 < time_1:
        time_1, time_2 = time_2, time_1
    # Calculate the difference
    difference = time_2 - time_1
    # Print the difference
    return difference

def time_difference_to_words(difference):
    minutes = difference.seconds // 60
    seconds = difference.seconds % 60
    hundredths = difference.microseconds // 10000
    return f'{minutes} minutes, {seconds} seconds, {hundredths} hundredths of second'

# %%
## Reused Dataframes

men_df = df[df['Gender'] == 'Men'].reset_index(drop=True)
women_df = df[df['Gender'] == 'Women'].reset_index(drop=True)

winners_df = df[df['Position'] == 1].reset_index(drop=True)
display(winners_df)

records_df = df[df['Notes'].isin(['WR', 'OR'])].reset_index(drop=True)
display(records_df)
# Out:
#     Year        Location Gender  Position                 Name  \
# 0   1896          Athens    Men         1       Spyridon Louis
# 1   1900           Paris    Men         1        Michel Théato
# 2   1904       St. Louis    Men         1         Thomas Hicks
# 3   1908          London    Men         1         Johnny Hayes
# 4   1912       Stockholm    Men         1         Ken McArthur
# 5   1920         Antwerp    Men         1   Hannes Kolehmainen
# 6   1924           Paris    Men         1       Albin Stenroos
# 7   1928       Amsterdam    Men         1    Boughera El Ouafi
# 8   1932     Los Angeles    Men         1   Juan Carlos Zabala
# 9   1936          Berlin    Men         1            Kitei Son
# 10  1948          London    Men         1        Delfo Cabrera
# 11  1952        Helsinki    Men         1         Emil Zátopek
# 12  1956       Melbourne    Men         1         Alain Mimoun
# 13  1960            Rome    Men         1         Abebe Bikila
# 14  1964           Tokyo    Men         1         Abebe Bikila
# 15  1968     Mexico City    Men         1           Mamo Wolde
# 16  1972          Munich    Men         1        Frank Shorter
# 17  1976        Montreal    Men         1  Waldemar Cierpinski
# 18  1980          Moscow    Men         1  Waldemar Cierpinski
# 19  1984     Los Angeles    Men         1         Carlos Lopes
# 20  1988           Seoul    Men         1       Gelindo Bordin
# 21  1992       Barcelona    Men         1      Hwang Young-Cho
# 22  1996         Atlanta    Men         1       Josia Thugwane
# 23  2000          Sydney    Men         1      Gezahegne Abera
# 24  2004          Athens    Men         1      Stefano Baldini
# 25  2008         Beijing    Men         1       Samuel Wanjiru
# 26  2012          London    Men         1    Stephen Kiprotich
# 27  2016  Rio de Janeiro    Men         1       Eliud Kipchoge
# 36        Ethiopia         Africa    2:23:07    OR        0 days 02:23:07
# 37           Kenya         Africa    2:24:04     -        0 days 02:24:04
# 38           Kenya         Africa    2:27:20     -        0 days 02:27:20
#     Year     Location Gender  Position                 Name     Nationality  \
# 0   1896       Athens    Men         1       Spyridon Louis          Greece
# 1   1908       London    Men         1         Johnny Hayes   United States
# 2   1912    Stockholm    Men         1         Ken McArthur    South Africa
# 3   1920      Antwerp    Men         1   Hannes Kolehmainen         Finland
# 4   1932  Los Angeles    Men         1   Juan Carlos Zabala       Argentina
# 5   1936       Berlin    Men         1            Kitei Son           Japan
# 6   1952     Helsinki    Men         1         Emil Zátopek  Czechoslovakia
# 7   1960         Rome    Men         1         Abebe Bikila        Ethiopia
# 8   1964        Tokyo    Men         1         Abebe Bikila        Ethiopia
# 9   1976     Montreal    Men         1  Waldemar Cierpinski    East Germany
# 10  1984  Los Angeles    Men         1         Carlos Lopes        Portugal
# 11  2008      Beijing    Men         1       Samuel Wanjiru           Kenya
# 12  1984  Los Angeles  Women         1          Joan Benoit   United States
# 13  2000       Sydney  Women         1      Naoko Takahashi           Japan
# 14  2012       London  Women         1          Tiki Gelana        Ethiopia
#
#         Continent Time_Taken Notes                   Time
# 0          Europe    2:58:50    OR        0 days 02:58:50
# 1   North America  2:55:18.4    WR 0 days 02:55:18.400000
# 2          Africa  2:36:54.8    OR 0 days 02:36:54.800000
# 3          Europe  2:32:35.8    WR 0 days 02:32:35.800000
# 4   South America    2:31:36    OR        0 days 02:31:36
# 5            Asia  2:29:19.2    OR 0 days 02:29:19.200000
# 6          Europe  2:23:03.2    OR 0 days 02:23:03.200000
# 7          Africa  2:15:16.2    WR 0 days 02:15:16.200000
# 8          Africa  2:12:11.2    WR 0 days 02:12:11.200000
# 9          Europe    2:09:55    OR        0 days 02:09:55
# 10         Europe    2:09:21    OR        0 days 02:09:21
# 11         Africa    2:06:32    OR        0 days 02:06:32
# 12  North America    2:24:52    OR        0 days 02:24:52
# 13           Asia    2:23:14    OR        0 days 02:23:14
# 14         Africa    2:23:07    OR        0 days 02:23:07

# %%
for gender in genders:
    # winners tables by gender
    gender_winners_df = winners_df[winners_df['Gender']==gender][['Year', 'Location', 'Gender', 'Name', 'Time_Taken', 'Notes']]
    print(f'{gender} Winners')
    display(gender_winners_df)
    export_df_as_markdown(gender_winners_df, f'winners_{gender.lower()}')

    # records tables by gender
    gender_records_df = records_df[records_df['Gender']==gender][['Year', 'Location', 'Gender', 'Name', 'Time_Taken', 'Notes']]
    print(f'{gender} Records')
    display(gender_records_df)
    export_df_as_markdown(gender_records_df, f'records_{gender.lower()}')
# Out:
# Men Winners
#     Year        Location Gender                 Name Time_Taken Notes
# 0   1896          Athens    Men       Spyridon Louis    2:58:50    OR
# 1   1900           Paris    Men        Michel Théato    2:59:45     -
# 2   1904       St. Louis    Men         Thomas Hicks    3:28:53     -
# 3   1908          London    Men         Johnny Hayes  2:55:18.4    WR
# 33  2000          Sydney  Women     Naoko Takahashi    2:23:14    OR
# 34  2004          Athens  Women      Mizuki Noguchi    2:26:20     -
# 35  2008         Beijing  Women    Constantina Diță    2:26:44     -
# 36  2012          London  Women         Tiki Gelana    2:23:07    OR
# 37  2016  Rio de Janeiro  Women      Jemima Sumgong    2:24:04     -
# 38  2020           Tokyo  Women   Peres Jepchirchir    2:27:20     -
# Women Records
#     Year     Location Gender             Name Time_Taken Notes
# 12  1984  Los Angeles  Women      Joan Benoit    2:24:52    OR
# 13  2000       Sydney  Women  Naoko Takahashi    2:23:14    OR
# 14  2012       London  Women      Tiki Gelana    2:23:07    OR

# %%
## Graph y axis formatting

def format_y_axis_times_from_minutes():
    # Get the current y-axis tick labels
    tick_labels = plt.gca().get_yticks()
    # Convert tick labels from float hours to "HH:MM" format
    tick_labels_formatted = [f"{int(minutes) // 60:02d}:{int(minutes) % 60:02d}" for minutes in tick_labels]
    plt.gca().set_yticklabels(tick_labels_formatted)

def format_y_axis_times():
    # Get the current y-axis tick labels
    tick_labels = plt.gca().get_yticks()
    # Convert tick labels from float hours to "HH:MM" format
    tick_labels_formatted = [f"{int(seconds) // 3600:02d}:{int(seconds) % 3600 // 60:02d}" for seconds in tick_labels]
    plt.gca().set_yticklabels(tick_labels_formatted)

# %%
#### Winning Times from 1896 to 2020 ###
# Setting up plot
plt.style.use('default')
plt.figure(figsize=(10, 6))
plt.xlabel('Year')
plt.ylabel('Time (hh:mm)')
plt.title('Winning Times From 1896 to 2020')
plt.grid(True, alpha=0.5, linestyle=":")    

# Plotting data for countries_of_interest using a for loop
for gender in genders:
    gender_data = winners_df[winners_df['Gender'] == gender]
    plt.plot(gender_data['Year'], gender_data['Time']/ pd.Timedelta(seconds=1), label=gender, linewidth=2) 

# Annotate rows with "WR" or "OR" in the notes column
for index, row in records_df.iterrows():
    plt.annotate(f"{str(row['Time']).split(' ')[-1][:8]} ({row['Notes']})",
                 xy=(row['Year'], row['Time'] / pd.Timedelta(seconds=1)),
                 xytext=(10,15),
                 textcoords='offset points',
                 rotation=45,
                 arrowprops=dict(arrowstyle="->"))
    
# Showing plot
plt.xticks(rotation='vertical',ticks=range(winners_df['Year'].min(), winners_df['Year'].max() + 1, 4))
# Calculate the tick positions
tick_positions = range(120*60, (210*60)+60, 15*60)
plt.yticks(tick_positions)
format_y_axis_times()

plt.legend(frameon=1, framealpha=1)
plt.savefig('figures/winning_times_plot.png', bbox_inches='tight')
plt.show()

# %%
### Total Finishers by Gender Each Year ###


for gender in genders:
    plt.style.use('default')
    grouped_counts = df[df['Gender'] == gender].groupby('Year').size()
    # Calculate the number of bars (assuming each bar represents a year)
    num_years = len(grouped_counts)
    #print(num_years)

    # Calculate the figure size based on the number of bars
    fig_width = (num_years // 2)  # Minimum width of 8 inches, adjust multiplier as needed
    fig_height = 6  # You can adjust this as needed
    plt.figure(figsize=(fig_width, fig_height))
    
    # Plot the grouped counts
    ax = grouped_counts.plot(kind='bar', color=['#85e085'], width=0.5)

    # Add labels and title
    plt.grid(True, alpha=0.5, linestyle=":")
    plt.xlabel('Year')
    plt.ylabel('Number of finishers')
    plt.title(f'Finishers Each Year ({gender})')
    # Annotate each bar with its count value
    for i, count in enumerate(grouped_counts):
        ax.annotate(str(count), xy=(i, count), ha='center', va='bottom')
        
    # Save plot as PNG
    plt.savefig(f'figures/{gender.lower()}_total_finishers_plot.png', bbox_inches='tight')
    # Show plot
    plt.show()

# %%
# Group by 'Gender' and 'Year' and count occurrences
grouped_counts = df.groupby(['Year', 'Continent']).size().unstack()
# Convert all float values in the DataFrame to integers
grouped_counts = grouped_counts.fillna(0).astype(int)

# Setting up plot
plt.style.use('default')
plt.figure(figsize=(10, 6))


# Calculate the total counts for each continent
continent_totals = grouped_counts.sum()

# Sort the columns (continents) by the total counts so continent with most counts at bottom
sorted_continents = continent_totals.sort_values(ascending=False).index

# Reorder the columns of grouped_counts DataFrame
grouped_counts_sorted = grouped_counts[sorted_continents]# Plot the stacked bar chart
ax = grouped_counts_sorted.plot.bar(stacked=True)

# Calculate the total number of finishers each year
yearly_totals = grouped_counts.sum(axis=1)

# Show legend with continent names
plt.grid(True, alpha=0.5, linestyle=":", axis='y')
plt.xlabel('Year')
plt.yticks(np.arange(0, yearly_totals.max() + 5, 25))
plt.ylabel('Number of Finishers')
plt.title('Number of Finishers by Continent (1896-2020)')
plt.legend()  

# Save plot as PNG
plt.savefig('figures/total_finishers_by_continent_stacked_plot.png', bbox_inches='tight')
# Show the plot
plt.show()

#### Tables behin the plot - absolute numbers and as percentages of finishers each year ####



# Divide each count by the corresponding yearly total to get percentages
grouped_perc = grouped_counts.div(yearly_totals, axis=0) * 100

# Convert all float values in the DataFrame to integers and add percentage signs
grouped_perc = grouped_perc.fillna(0).astype(int).astype(str) + '%'

# Replace '0%' with '-'
grouped_perc[grouped_perc == '0%'] = '-'
# Replace '0' with '-'
grouped_counts[grouped_counts == 0] = '-'

print('Total finishers by continent (number)')
display(grouped_counts)
export_df_as_markdown(grouped_counts.reset_index(), 'total_finishers_by_continent_number')

print('Total finishers by continent as a percentage of runners each year')
display(grouped_perc)
export_df_as_markdown(grouped_perc.reset_index(), 'total_finishers_by_continent_percentage')


other_continents = df[df['Continent']=='Other'][['Year', 'Location', 'Gender', 'Position', 'Name', 'Nationality', 'Time_Taken']].sort_values(by='Year')
print('"Other" continent in more detail')
display(other_continents)
export_df_as_markdown(other_continents, 'other_continent_finishers')
# Out:
# Total finishers by continent (number)
# Continent Africa Asia  Europe North America Oceania Other South America
# Year
# 1896           -    -       3             -       -     -             -
# 1900           -    -       4             1       -     -             -
# 1904           -    -       1             2       -     -             -
# 1908           1    -      12            13       -     -             -
# 1912           2    -      19            13       -     -             -
# 1920           -    5      22             6       1     -             1
# 1924           1    1      20             7       -     -             1
# 1928           1    3      39            13       -     -             1
# 1932           -    3       8             6       -     -             3
# 1936           3    4      29             3       -     -             3
# 1948           2    3      15             6       -     -             4
# 1952           4    6      33             5       2     -             3
# 1956           4    8      16             2       3     -             -
# 1960           9   10      30             4       5     -             4
# 1964          11   11      23             6       6     -             1
# 1968          11   11      20             8       4     -             3
# 1972           6    7      29             9       4     -             7
# 1976           -   11      28            14       4     -             3
# 1980          15    8      25             1       2     -             2
# 1984          22   19      46            20       7     -             8
# 1988          36   26      50            30      15     -             5
# 1992          28   21      42            15       6     3             9
# 1996          32   29      63            25       8     -            18
# 2000          29   24      43            10       7     2            11
# 2004          25   34      57            16       7     -             8
# 2008          28   31      57            13       6     -            10
# 2012          35   39      77            15       7     1            18
# 2016          45   68      92            20       6     1            40
# 2020          26   26      57            18       8     1            12
# Total finishers by continent as a percentage of runners each year
# Continent Africa Asia Europe North America Oceania Other South America
# Year
# 1896           -    -   100%             -       -     -             -
# 1900           -    -    80%           20%       -     -             -
# 1904           -    -    33%           66%       -     -             -
# 1908          3%    -    46%           50%       -     -             -
# 1912          5%    -    55%           38%       -     -             -
# 1920           -  14%    62%           17%      2%     -            2%
# 1924          3%   3%    66%           23%       -     -            3%
# 1928          1%   5%    68%           22%       -     -            1%
# 1932           -  15%    40%           30%       -     -           15%
# 1936          7%   9%    69%            7%       -     -            7%
# 1948          6%  10%    50%           20%       -     -           13%
# 1952          7%  11%    62%            9%      3%     -            5%
# 1956         12%  24%    48%            6%      9%     -             -
# 1960         14%  16%    48%            6%      8%     -            6%
# 1964         18%  18%    39%           10%     10%     -            1%
# 1968         19%  19%    35%           14%      7%     -            5%
# 1972          9%  11%    46%           14%      6%     -           11%
# 1976           -  18%    46%           23%      6%     -            5%
# 1980         28%  15%    47%            1%      3%     -            3%
# 1984         18%  15%    37%           16%      5%     -            6%
# 1988         22%  16%    30%           18%      9%     -            3%
# 1992         22%  16%    33%           12%      4%    2%            7%
# 1996         18%  16%    36%           14%      4%     -           10%
# 2000         23%  19%    34%            7%      5%    1%            8%
# 2004         17%  23%    38%           10%      4%     -            5%
# 2008         19%  21%    39%            8%      4%     -            6%
# 2012         18%  20%    40%            7%      3%     -            9%
# 2016         16%  25%    33%            7%      2%     -           14%
# 2020         17%  17%    38%           12%      5%     -            8%
# "Other" continent in more detail
#       Year        Location Gender  Position                   Name  \
# 920   1992       Barcelona    Men        22        Yakov Tolstikov
# 1741  1992       Barcelona  Women         1     Valentina Yegorova
# 1748  1992       Barcelona  Women         8    Ramilya Burangulova
# 1166  2000          Sydney    Men        71       Calisto da Costa
# 1885  2000          Sydney  Women        43          Aguida Amaral
# 1380  2012          London    Men        47            Guor Marial
# 1507  2016  Rio de Janeiro    Men        89            Yonas Kinde
# 1573  2020           Tokyo    Men        16  Tachlowini Gabriyesos
#
#                        Nationality Time_Taken
# 920                   Unified Team    2:17:04
# 1741                  Unified Team    2:32:41
# 1748                  Unified Team    2:38:46
# 1166   Individual Olympic Athletes    2:33:11
# 1885   Individual Olympic Athletes    3:10:55
# 1380  Independent Olympic Athletes    2:19:32
# 1507          Refugee Olympic Team    2:24:08
# 1573          Refugee Olympic Team    2:14:02

# %%
#### Tables for closest races, closest second places, top 10 runners ever ####

# Sort DataFrame by 'Year' and 'Position' to ensure chronological order
medals_df = df[df['Position'].isin([1, 2, 3])].sort_values(by=['Gender', 'Year','Position']).reset_index(drop=True)

# Calculate time difference and difference to words
medals_df['Time_Delta'] = medals_df['Time'].diff()
medals_df['Difference'] = medals_df['Time_Delta'].apply(time_difference_to_words)

# Set NaN for the first occurrence of each year
medals_df.loc[medals_df['Position'] == 1, ['Time_Delta', 'Difference']] = None

# Display the DataFrame
display(medals_df)

second_place_df = medals_df[medals_df['Position']==2].reset_index(drop=True)
third_place_df = medals_df[medals_df['Position']==3].reset_index(drop=True)
not_first_place_df = medals_df[medals_df['Position']!=1].reset_index(drop=True)

for gender in genders:
    
    # Closest Wins
    gender_second_place_df = second_place_df[second_place_df['Gender']==gender].sort_values(by='Time_Delta')
    closest_and_easiest_races = pd.concat([gender_second_place_df.head(3), gender_second_place_df.tail(3)])
    closest_and_easiest_races = closest_and_easiest_races[['Year', 'Location', 'Gender','Position', 'Name', 'Nationality', 'Time_Taken', 'Difference']]
    closest_and_easiest_races = closest_and_easiest_races.rename(columns={'Difference': 'Time behind 1st'})
    print(f'{gender} closest and easiest wins')
    display(closest_and_easiest_races)
    export_df_as_markdown(closest_and_easiest_races, f'{gender.lower()}_closest_and_easiest_races')
    
    gender_third_place_df = third_place_df[third_place_df['Gender']==gender].sort_values(by='Time_Delta')
    closest_and_easiest_races = pd.concat([gender_third_place_df.head(3), gender_third_place_df.tail(3)])
    closest_and_easiest_races = closest_and_easiest_races[['Year', 'Location', 'Gender','Position', 'Name', 'Nationality', 'Time_Taken', 'Difference']]
    closest_and_easiest_races = closest_and_easiest_races.rename(columns={'Difference': 'Time behind 2nd'})
    print(f'{gender} closest and easiest 2nd places')
    display(closest_and_easiest_races)
    export_df_as_markdown(closest_and_easiest_races, f'{gender.lower()}_closest_and_easiest_2nd_places')
    
    # all time top 10 finishes
    fastest_ever = df[df['Gender']==gender].sort_values(by='Time').reset_index(drop=True)
    top_10_fastest = fastest_ever.head(10)
    top_10_fastest = top_10_fastest[['Year', 'Location', 'Gender','Position', 'Name', 'Nationality', 'Time_Taken']]
    print(f'{gender} fastest ever top 10')
    display(top_10_fastest)
    export_df_as_markdown(top_10_fastest, f'{gender.lower()}_top_10_ever')
# Out:
#      Year        Location Gender  Position                 Name  \
# 0    1896          Athens    Men         1       Spyridon Louis
# 1    1896          Athens    Men         2  Charilaos Vasilakos
# 2    1896          Athens    Men         3        Gyula Kellner
# 3    1900           Paris    Men         1        Michel Théato
# 4    1900           Paris    Men         2       Émile Champion
# ..    ...             ...    ...       ...                  ...
# 112  2016  Rio de Janeiro  Women         2         Eunice Kirwa
# 113  2016  Rio de Janeiro  Women         3          Mare Dibaba
# 114  2020           Tokyo  Women         1    Peres Jepchirchir
# 33          Kenya    2:24:45  1 minutes, 23 seconds, 0 hundredths of second
# Women fastest ever top 10
#    Year        Location Gender  Position                       Name  \
# 0  2012          London  Women         1                Tiki Gelana
# 1  2012          London  Women         2             Priscah Jeptoo
# 2  2000          Sydney  Women         1            Naoko Takahashi
# 3  2000          Sydney  Women         2                Lidia Șimon
# 4  2012          London  Women         3  Tatyana Petrova Arkhipova
# 5  2012          London  Women         4     Mary Jepkosgei Keitany
# 6  2016  Rio de Janeiro  Women         1             Jemima Sumgong
# 7  2016  Rio de Janeiro  Women         2               Eunice Kirwa
# 8  2016  Rio de Janeiro  Women         3                Mare Dibaba
# 9  2012          London  Women         5     Tetyana Hamera-Shmyrko
#
#   Nationality Time_Taken
# 0    Ethiopia    2:23:07
# 1       Kenya    2:23:12
# 2       Japan    2:23:14
# 3     Romania    2:23:22
# 4      Russia    2:23:29
# 5       Kenya    2:23:56
# 6       Kenya    2:24:04
# 7     Bahrain    2:24:13
# 8    Ethiopia    2:24:30
# 9     Ukraine    2:24:32

# %%
#### Medals plot ####

# Plotting
plt.style.use('default')
plt.figure(figsize=(10, 6))
plt.xlabel('Year')
plt.ylabel('Time (hh:mm)')
plt.title('Medal Times From 1896 to 2020')
plt.grid(True, alpha=0.5, linestyle=":")

for gender in genders:
    # Plotting first positions with a faded grey color
    first_positions = medals_df[(medals_df['Position'] == 1)&(medals_df['Gender'] == gender)]
    # Convert the 'Time' column to total seconds
    line_colour = 'lightskyblue' if gender == 'Men' else 'violet'
    plt.plot(first_positions['Year'], first_positions['Time'].dt.total_seconds(), color=line_colour, alpha=0.5, label=gender)

# Plot each medal finisher
for position, color in [(1, '#ffd700'), (2, '#8c8c8c'), (3, '#e65c00')]:
    finishers = medals_df[medals_df['Position'] == position]
    plt.scatter(finishers['Year'], finishers['Time'].dt.total_seconds(), color=color, marker='.', alpha=1, s=50, label=f'{["Gold", "Silver", "Bronze"][position-1]}')
    
# Showing plot
plt.xticks(rotation='vertical',ticks=range(medals_df['Year'].min(), medals_df['Year'].max() + 1, 4))

# Calculate the tick positions
tick_positions = range(120*60, (240*60)+60, 15*60)
plt.yticks(tick_positions)
format_y_axis_times()
plt.legend()

plt.savefig('figures/medal_times_plot.png', bbox_inches='tight')
plt.show()

# %%
#### Differences between Average Men and Women finishers ####

men_and_women_averages = df[df['Year']>=1984].groupby(['Gender', 'Year'])['Time'].mean().reset_index()
# Separate calculations for men and women
men_averages = men_and_women_averages[men_and_women_averages['Gender'] == 'Men'].set_index('Year')
women_averages = men_and_women_averages[men_and_women_averages['Gender'] == 'Women'].set_index('Year')

# Merge men and women dataframes on the 'Year' index
merged_averages = pd.merge(men_averages, women_averages, on='Year', suffixes=('_Men', '_Women'))

merged_averages['Difference'] = (merged_averages['Time_Women'] - merged_averages['Time_Men']) 
# Calculate percentage difference between men and women
merged_averages['Percentage_Difference'] = (merged_averages['Time_Women'] - merged_averages['Time_Men']) / merged_averages['Time_Men'] * 100

display(merged_averages)

# Plotting
plt.figure(figsize=(10, 6))
plt.grid(True, alpha=0.5, linestyle=":")

plt.scatter(merged_averages.index, merged_averages['Percentage_Difference'], label='Percentage Difference', marker='o', color='green')
for i, row in merged_averages.iterrows():
    plt.annotate(f"{row['Percentage_Difference']:.2f}%", 
                 (i, row['Percentage_Difference']),
                 textcoords="offset points",
                 xytext=(25,-3), 
                 ha='center')

# Fit a linear regression line
coefficients = np.polyfit(merged_averages.index, merged_averages['Percentage_Difference'], 1)
poly = np.poly1d(coefficients)
x_values = np.linspace(min(merged_averages.index), max(merged_averages.index), 100)
y_values = poly(x_values)
plt.plot(x_values, y_values, color='orange', linestyle='--', label='Line of Best Fit')

# Labels and title
plt.xlabel('Year')
plt.ylabel('Percentage Women Slower Than Men')
plt.title('Differences in Between Average Finishing Times between Women and Men (1984-2020)')
plt.legend()
plt.xticks(rotation='vertical',ticks=range(men_and_women_averages['Year'].min(), men_and_women_averages['Year'].max() + 1, 4))


# Show plot
plt.savefig('figures/gender_average_time_difference_plot.png', bbox_inches='tight')
plt.show()
# Out:
#      Gender_Men                  Time_Men Gender_Women  \
# Year
# 1984        Men 0 days 02:24:06.858974358        Women
# 1988        Men 0 days 02:29:55.153061224        Women
# 1992        Men 0 days 02:25:51.632183908        Women
# 1996        Men 0 days 02:26:17.672727272        Women
# 2000        Men 0 days 02:23:34.209876543        Women
# 2004        Men 0 days 02:22:21.888888888        Women
# 2008        Men 0 days 02:21:03.552631578        Women
# 2012        Men 0 days 02:20:35.505882352        Women
# 2016        Men 0 days 02:22:22.841726618        Women
# 2020        Men 0 days 02:18:46.506666666        Women
#
#                     Time_Women                Difference  \
# Year
# 1984 0 days 02:38:59.840909090 0 days 00:14:52.981934732
# 1988    0 days 02:42:18.984375 0 days 00:12:23.831313776
# 1992 0 days 02:49:18.729729729 0 days 00:23:27.097545821
# 1996 0 days 02:41:41.830769230 0 days 00:15:24.158041958
# 2000 0 days 02:37:10.311111111 0 days 00:13:36.101234568
# 2004 0 days 02:45:29.045454545 0 days 00:23:07.156565657
# 2008 0 days 02:36:09.144927536 0 days 00:15:05.592295958
# 2012 0 days 02:36:08.336448598 0 days 00:15:32.830566246
# 2016 0 days 02:43:34.443609022 0 days 00:21:11.601882404
# 2020 0 days 02:37:53.424657534 0 days 00:19:06.917990868
#
#       Percentage_Difference
# Year
# 1984              10.327241
# 1988               8.269246
# 1992              16.078116
# 1996              10.528509
# 2000               9.473895
# 2004              16.239459
# 2008              10.699907
# 2012              11.058383
# 2016              14.884999
# 2020              13.774300

# %%
#### Repeat Runners and how many people have run how many times ####
repeat_runners_df = df.groupby(['Name', 'Nationality', 'Gender']).agg({ 'Name': 'count', 'Year': list}).rename(columns={'Name': 'Number of Finishes'}).reset_index()
how_many_repeats_runners_df = repeat_runners_df.groupby(['Number of Finishes', 'Gender']).size().unstack()
how_many_repeats_runners_df = how_many_repeats_runners_df.fillna(0).astype(int)
print('Number of times athletes have finshed')
display(how_many_repeats_runners_df.reset_index())
export_df_as_markdown(how_many_repeats_runners_df.reset_index(), f'number_of_times_athletes_have_finished')


repeat_runners_df = repeat_runners_df[repeat_runners_df['Number of Finishes']>3].sort_values(by=['Number of Finishes', 'Gender'], ascending=[False, True]).reset_index(drop=True)
display(repeat_runners_df)
export_df_as_markdown(repeat_runners_df, 'athletes_finshing_at_least_four_times')
# Out:
# Number of times athletes have finshed
# Gender  Number of Finishes   Men  Women
# 0                        1  1138    501
# 1                        2   199     80
# 2                        3    23      7
# 3                        4     7      4
# 4                        5     0      1
#                    Name  Nationality Gender  Number of Finishes  \
# 0         Érika Olivera        Chile  Women                   5
# 1   Baikuntha Manandhar        Nepal    Men                   4
# 2   Hussein Ahmed Salah     Djibouti    Men                   4
# 3     José Amado García    Guatemala    Men                   4
# 4         Karel Lismont      Belgium    Men                   4
# 5        Pavel Loskutov      Estonia    Men                   4
# 6    Robert de Castella    Australia    Men                   4
# 7      Steve Moneghetti    Australia    Men                   4
# 8      Helalia Johannes      Namibia  Women                   4
# 9           Lidia Șimon      Romania  Women                   4
# 10  Lisa Jane Weightman    Australia  Women                   4
# 11      Lorraine Moller  New Zealand  Women                   4
#
#                               Year
# 0   [1996, 2000, 2004, 2012, 2016]
# 1         [1976, 1980, 1984, 1988]
# 2         [1984, 1988, 1992, 1996]
# 3         [2004, 2008, 2012, 2016]
# 4         [1972, 1976, 1980, 1984]
# 5         [1996, 2000, 2004, 2008]
# 6         [1980, 1984, 1988, 1992]
# 7         [1988, 1992, 1996, 2000]
# 8         [2008, 2012, 2016, 2020]
# 9         [1996, 2000, 2008, 2012]
# 10        [2008, 2012, 2016, 2020]
# 11        [1984, 1988, 1992, 1996]

# %%
### Medal Tally ###
medals_df_updated = medals_df
medals_df_updated['Position'] = medals_df['Position'].replace({1: 'Gold', 2: 'Silver', 3: 'Bronze'})
country_medal_count = medals_df_updated.groupby(['Nationality', 'Position']).size().unstack()
country_medal_count['Total Medals'] = country_medal_count.sum(axis=1)
country_medal_count = country_medal_count.sort_values(by='Total Medals', ascending=False).fillna(0).astype(int)

ordered_columns = ['Gold', 'Silver', 'Bronze', 'Total Medals']
country_medal_count = country_medal_count.reindex(columns=ordered_columns, fill_value=0)
country_medal_count = country_medal_count.reset_index()

display(country_medal_count.replace(0,'-'))
export_df_as_markdown(country_medal_count.replace(0,'-'), 'country_medal_count')

top_golds = country_medal_count.sort_values(by='Gold', ascending=False)
display(top_golds.head(5))
export_df_as_markdown(top_golds.head(5), 'top_five_total_golds')
# Out:
# Position     Nationality Gold Silver Bronze  Total Medals
# 0                  Kenya    5      7      3            15
# 1          United States    4      2      7            13
# 2               Ethiopia    6      1      4            11
# 3                  Japan    3      3      3             9
# 4                Finland    2      -      3             5
# 5          Great Britain    -      4      1             5
# 6                 France    3      2      -             5
# 7                Belgium    -      1      3             4
# 8                  Italy    2      1      1             4
# 9           South Africa    2      2      -             4
# 10              Portugal    2      -      1             3
# 11             Argentina    2      1      -             3
# 12          East Germany    2      -      1             3
# 13           New Zealand    -      -      3             3
# 14                Russia    -      1      1             2
# 15           South Korea    1      1      -             2
# 16                Greece    1      1      -             2
# 17               Romania    1      1      -             2
# 18                Sweden    -      -      2             2
# 19               Morocco    -      2      -             2
# 20           Netherlands    -      2      -             2
# 21                Norway    -      1      -             1
# 22          Soviet Union    -      -      1             1
# 23                Uganda    1      -      -             1
# 24          Unified Team    1      -      -             1
# 25               Ireland    -      1      -             1
# 26             Australia    -      1      -             1
# 27               Hungary    -      -      1             1
# 28               Germany    -      -      1             1
# 29               Estonia    -      1      -             1
# 30              Djibouti    -      -      1             1
# 31        Czechoslovakia    1      -      -             1
# 32                 China    -      -      1             1
# 33                 Chile    -      1      -             1
# 34                Brazil    -      -      1             1
# 35               Bahrain    -      1      -             1
# 36            Yugoslavia    -      1      -             1
# Position    Nationality  Gold  Silver  Bronze  Total Medals
# 2              Ethiopia     6       1       4            11
# 0                 Kenya     5       7       3            15
# 1         United States     4       2       7            13
# 3                 Japan     3       3       3             9
# 6                France     3       2       0             5

# %%
#### Repeat Medalists ####

name_medal_count = medals_df_updated.groupby(['Gender', 'Name', 'Position']).size().unstack()
name_medal_count['Total Medals'] = name_medal_count.sum(axis=1)
name_medal_count = name_medal_count[name_medal_count['Total Medals']>1].sort_values(by='Total Medals', ascending=False).fillna(0).astype(int)

ordered_columns = ['Gold', 'Silver', 'Bronze', 'Total Medals']
name_medal_count = name_medal_count.reindex(columns=ordered_columns, fill_value=0)

display(name_medal_count.replace(0,'-'))
export_df_as_markdown(name_medal_count.replace(0,'-').reset_index(), 'name_medal_count')

top_golds = medals_df_updated.groupby(['Gender', 'Name', 'Nationality', 'Position']).agg(
    Total_Medals=('Position', 'count'),  # Count the number of medals for each group
    Years=('Year', list)  # Collect the list of years for each group
).reset_index()
# Filter based on the 'Gold' column and the 'Total_Medals' column
top_golds = top_golds[(top_golds['Position'] == 'Gold') & (top_golds['Total_Medals'] > 1)].reset_index(drop=True)

display(top_golds)
export_df_as_markdown(top_golds, 'top_gold_medals')
# Out:
# Position                   Gold Silver Bronze  Total Medals
# Gender Name
# Men    Abebe Bikila           2      -      -             2
#        Eliud Kipchoge         2      -      -             2
#        Erick Wainaina         -      1      1             2
#        Frank Shorter          1      1      -             2
#        Karel Lismont          -      1      1             2
#        Mamo Wolde             1      -      1             2
#        Waldemar Cierpinski    2      -      -             2
# Women  Catherine Ndereba      -      2      -             2
#        Rosa Mota              1      -      1             2
#        Valentina Yegorova     1      1      -             2
#        Yuko Arimori           -      1      1             2
#   Gender                 Name   Nationality Position  Total_Medals  \
# 0    Men         Abebe Bikila      Ethiopia     Gold             2
# 1    Men       Eliud Kipchoge         Kenya     Gold             2
# 2    Men  Waldemar Cierpinski  East Germany     Gold             2
#
#           Years
# 0  [1960, 1964]
# 1  [2016, 2020]
# 2  [1976, 1980]
